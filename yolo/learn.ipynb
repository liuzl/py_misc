# %%
from ultralytics import YOLO
from PIL import ImageDraw
from PIL import Image

# %%
model = YOLO("yolov8s-seg.pt")

# %%
results = model.predict("cat_dog.jpg")
# Out:
# image 1/1 /Users/zliu/git/py_misc/yolo/cat_dog.jpg: 448x640 1 cat, 1 dog, 83.5ms
# Speed: 1.5ms preprocess, 83.5ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)

# %%
result = results[0]

# %%
masks = result.masks
len(masks)
# Out:
# 2

# %%
mask1 = masks[0]

# %%
mask = mask1.data[0].numpy()
polygon = mask1.xy[0]

# %%
Image.fromarray(mask,"I")
# Out:
# <PIL.Image.Image image mode=I size=640x448>

# %%
img = Image.open("cat_dog.jpg")
draw = ImageDraw.Draw(img)
draw.polygon(polygon,outline=(0,255,0), width=5)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x415>

# %%
mask2 = masks[1]
mask = mask2.data[0].numpy()
polygon = mask2.xy[0]
Image.fromarray(mask,"I")
# Out:
# <PIL.Image.Image image mode=I size=640x448>

# %%
draw.polygon(polygon,outline=(0,255,0), width=5)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x415>
