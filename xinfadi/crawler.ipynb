# %%
import pandas as pd

# %%
ret = pd.read_html('http://www.xinfadi.com.cn/marketanalysis/4/list/1.shtml',header=0)

# %%
df = ret[1]
del df['Unnamed: 7']

# %%
df
# Out:
#        品名   最低价    平均价   最高价          规格 单位        发布日期
# 0     海螺丝  15.0  15.50  16.0           活  斤  2019-07-29
# 1     大海螺  20.0  20.50  21.0           活  斤  2019-07-29
# 2     大蛏子  11.0  11.50  12.0      >6cm/活  斤  2019-07-29
# 3     大蛏子  10.0  10.50  11.0      <6cm/活  斤  2019-07-29
# 4      海虹   4.0   4.25   4.5           活  斤  2019-07-29
# 5     海瓜子   4.5   4.75   5.0           活  斤  2019-07-29
# 6      文蛤   8.0   8.50   9.0      >5cm/活  斤  2019-07-29
# 7      文蛤   7.0   7.50   8.0      <5cm/活  斤  2019-07-29
# 8      白蛤   3.0   3.50   4.0           活  斤  2019-07-29
# 9      青蛤  11.0  11.50  12.0           活  斤  2019-07-29
# 10     花蛤   3.5   3.75   4.0           活  斤  2019-07-29
# 11     毛蚶   3.0   3.50   4.0        活/南方  斤  2019-07-29
# 12     毛蚶   4.0   4.50   5.0        活/北方  斤  2019-07-29
# 13  仿野生甲鱼  45.0  45.50  46.0           活  斤  2019-07-29
# 14   养殖甲鱼  16.0  16.50  17.0           活  斤  2019-07-29
# 15     蚕蛹  50.0  50.50  51.0           活  斤  2019-07-29
# ...
