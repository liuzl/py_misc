# %%
import pandas as pd

# %%
url = 'http://credit.heze.gov.cn/xygs/showDetail.do?recid=55A3863DD6D24B9DBA15CB0530F28257&messageid=89F0267EC0D6430CB0AAC46317DFC9BD&recflag=IRECID&d=1652858829440'

# %%
df = pd.read_html(url)

# %%
df[0]
# Out:
#              Unnamed: 0                                         Unnamed: 1
# 0               行政相对人名称                                        北京经道堂中医药研究院
# 1   行政相对人代码_1(统一社会信用代码)                                 91110108MA00GXEX3E
# 2      行政相对人代码_2(工商注册号)                                                NaN
# 3                 法定代表人                                                王洪刚
# 4             行政处罚决定书文号                               成市监行处字〔 2021 〕2202 号
# 5                违法行为类型                                             组织策划传销
# 6                  违法事实  北京经道堂国际中医药研究院系涉嫌传销违法主体，其在从事涉案的传销活动过程中使用北京经道堂国际...
# 7                  处罚依据  《禁止传销条例》第七条（二）（三）所规定的传销行为，根据《禁止传销条例》第二十四条第一款“有...
# 8                  处罚类别                                              罚款;罚款
# 9                  处罚内容  1、责令当事人停止传销活动； 2、没收非法财物13041301.90元； 3、罚款20000...
# 10             罚款金额(万元)                                                200
# ...

# %%
import lxml
