# %%
# !pip install stanza
# Out:
# ...
#      |████████████████████████████████| 334 kB 177 kB/s eta 0:00:01
# ...

# %%
import stanza

# %%
nlp = stanza.Pipeline("zh")
# Out:
# 2021-06-12 22:02:14 INFO: "zh" is an alias for "zh-hans"
# 2021-06-12 22:02:14 INFO: Loading these models for language: zh-hans (Simplified_Chinese):
# ...
# | Processor | Package   |
# -------------------------
# | tokenize  | gsdsimp   |
# | pos       | gsdsimp   |
# | lemma     | gsdsimp   |
# | depparse  | gsdsimp   |
# | sentiment | ren       |
# | ner       | ontonotes |
# ...
#
# 2021-06-12 22:02:14 INFO: Use device: cpu
# 2021-06-12 22:02:14 INFO: Loading: tokenize
# 2021-06-12 22:02:14 INFO: Loading: pos
# 2021-06-12 22:02:14 INFO: Loading: lemma
# 2021-06-12 22:02:14 INFO: Loading: depparse
# 2021-06-12 22:02:15 INFO: Loading: sentiment
# 2021-06-12 22:02:16 INFO: Loading: ner
# 2021-06-12 22:02:17 INFO: Done loading processors!

# %%
stanza.download('zh')
# Out:
# ...
# 2021-06-12 21:28:11 INFO: "zh" is an alias for "zh-hans"
# 2021-06-12 21:28:11 INFO: Downloading default packages for language: zh-hans (Simplified_Chinese)...
# ...
# 2021-06-12 22:01:55 INFO: Finished downloading models and saved to /Users/zliu/stanza_resources.

# %%
content = open('data.json').read()
import json
doc = json.loads(content)
doc_text = doc['text']

# %%
nlp(doc_text)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "6",
#       "lemma": "6",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 2,
#       "deprel": "nummod",
#       "start_char": 2,
#       "end_char": 3,
#       "ner": "S-CARDINAL"
#     },
#     {
#       "id": 2,
#       "text": "月",
#       "lemma": "月",
#       "upos": "NOUN",
#       "xpos": "NNB",
#       "head": 4,
#       "deprel": "clf",
#       "start_char": 3,
#       "end_char": 4,
#       "ner": "O"
#     },
#     {
#       "id": 3,
#       "text": "11",
#       "lemma": "11",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumType=Card",
#       "head": 4,
#       "deprel": "nummod",
#       "start_char": 4,
#       "end_char": 6,
#       "ner": "S-CARDINAL"
#     },
#     {
#       "id": 4,
#       "text": "日",
#       "lemma": "日",
#       "upos": "NOUN",
#       "xpos": "NNB",
#       "head": 14,
#       "deprel": "nmod:tmod",
#       "start_char": 6,
# ...
