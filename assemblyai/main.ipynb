# %%
import os
import requests

# %%
key = os.environ['assemblyai_key']

# %%
endpoint = "https://api.assemblyai.com/v2/transcript"
json = {
    "audio_url": "https://bit.ly/3yxKEIY"
}
headers = {
    "authorization": key,
    "content-type": "application/json"
}
response = requests.post(endpoint, json=json, headers=headers)

# %%
ret = response.json()

# %%
endpoint = "https://api.assemblyai.com/v2/transcript/%s" % ret['id']
headers = {
    "authorization": key,
}
response1 = requests.get(endpoint, headers=headers)

# %%
response1.json()
# Out:
# {'id': 'oy1fef7hns-62a8-4fe6-97a1-8c2c0c5ece41',
#  'language_model': 'assemblyai_default',
#  'acoustic_model': 'assemblyai_default',
#  'language_code': 'en_us',
#  'status': 'completed',
#  'audio_url': 'https://bit.ly/3yxKEIY',
#  'text': 'You know, demons on TV like that. And and for people to expose themselves to being rejected on TV or, you know, humili humiliated by Fear Factor or, you know.',
#  'words': [{'text': 'You',
#    'start': 430,
#    'end': 522,
#    'confidence': 0.99871,
#    'speaker': None},
#   {'text': 'know,',
#    'start': 536,
#    'end': 858,
#    'confidence': 0.99921,
#    'speaker': None},
#   {'text': 'demons',
#    'start': 944,
#    'end': 1402,
#    'confidence': 0.99509,
#    'speaker': None},
#   {'text': 'on',
#    'start': 1426,
#    'end': 1578,
#    'confidence': 0.9996,
#    'speaker': None},
#   {'text': 'TV',
#    'start': 1604,
#    'end': 1894,
#    'confidence': 0.9786,
#    'speaker': None},
#   {'text': 'like',
#    'start': 1942,
#    'end': 2118,
#    'confidence': 0.99969,
#    'speaker': None},
#   {'text': 'that.',
#    'start': 2144,
#    'end': 2334,
#    'confidence': 0.99953,
#    'speaker': None},
#   {'text': 'And',
#    'start': 2372,
#    'end': 2754,
#    'confidence': 0.99061,
#    'speaker': None},
#   {'text': 'and',
#    'start': 2852,
#    'end': 3114,
#    'confidence': 0.86576,
#    'speaker': None},
#   {'text': 'for',
#    'start': 3152,
#    'end': 3354,
#    'confidence': 0.88397,
#    'speaker': None},
#   {'text': 'people',
#    'start': 3392,
#    'end': 3630,
#    'confidence': 0.99953,
#    'speaker': None},
#   {'text': 'to',
#    'start': 3680,
#    'end': 4074,
#    'confidence': 0.99399,
#    'speaker': None},
#   {'text': 'expose',
#    'start': 4172,
#    'end': 4558,
#    'confidence': 0.99967,
#    'speaker': None},
#   {'text': 'themselves',
#    'start': 4594,
#    'end': 4974,
#    'confidence': 0.66975,
#    'speaker': None},
#   {'text': 'to',
#    'start': 5072,
#    'end': 5298,
#    'confidence': 0.99923,
#    'speaker': None},
#   {'text': 'being',
#    'start': 5324,
#    'end': 5514,
#    'confidence': 0.99939,
#    'speaker': None},
#   {'text': 'rejected',
#    'start': 5552,
#    'end': 6058,
#    'confidence': 0.9998,
#    'speaker': None},
#   {'text': 'on',
#    'start': 6094,
#    'end': 6222,
#    'confidence': 0.99987,
#    'speaker': None},
#   {'text': 'TV',
#    'start': 6236,
#    'end': 6574,
#    'confidence': 0.56787,
#    'speaker': None},
#   {'text': 'or,',
#    'start': 6622,
#    'end': 7086,
#    'confidence': 0.99765,
#    'speaker': None},
#   {'text': 'you',
#    'start': 7208,
#    'end': 7422,
#    'confidence': 0.99804,
#    'speaker': None},
#   {'text': 'know,',
#    'start': 7436,
#    'end': 7650,
#    'confidence': 0.9994,
#    'speaker': None},
#   {'text': 'humili',
#    'start': 7700,
#    'end': 8206,
#    'confidence': 0.35865,
#    'speaker': None},
#   {'text': 'humiliated',
#    'start': 8278,
#    'end': 8950,
#    'confidence': 0.5512,
#    'speaker': None},
#   {'text': 'by',
#    'start': 9010,
#    'end': 9270,
#    'confidence': 0.89037,
#    'speaker': None},
#   {'text': 'Fear',
#    'start': 9320,
#    'end': 9598,
#    'confidence': 0.99843,
#    'speaker': None},
#   {'text': 'Factor',
#    'start': 9634,
#    'end': 9881,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'or,',
#    'start': 9894,
#    'end': 10141,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'you',
#    'start': 10154,
#    'end': 10401,
#    'confidence': 1.0,
#    'speaker': None},
#   {'text': 'know.',
#    'start': 10414,
#    'end': 11640,
#    'confidence': 1.0,
#    'speaker': None}],
#  'utterances': None,
#  'confidence': 0.924453666666667,
#  'audio_duration': 12,
#  'punctuate': True,
#  'format_text': True,
#  'dual_channel': None,
#  'webhook_url': None,
#  'webhook_status_code': None,
#  'speed_boost': False,
#  'auto_highlights_result': None,
#  'auto_highlights': False,
#  'audio_start_from': None,
#  'audio_end_at': None,
#  'word_boost': [],
#  'boost_param': None,
#  'filter_profanity': False,
#  'redact_pii': False,
#  'redact_pii_audio': False,
#  'redact_pii_audio_quality': None,
#  'redact_pii_policies': None,
#  'redact_pii_sub': None,
#  'speaker_labels': False,
#  'content_safety': False,
#  'iab_categories': False,
#  'content_safety_labels': {'status': 'unavailable',
#   'results': [],
#   'summary': {}},
#  'iab_categories_result': {'status': 'unavailable',
#   'results': [],
#   'summary': {}},
#  'language_detection': False,
#  'custom_spelling': None,
#  'disfluencies': False,
#  'sentiment_analysis': False,
#  'auto_chapters': False,
#  'chapters': None,
#  'sentiment_analysis_results': None,
#  'entity_detection': False,
#  'entities': None}
