# %%
from herbie import Herbie
H = Herbie('2021-07-01 12:00', model='hrrr', product='sfc', fxx=6)
# Out:
# ✅ Found ┊ model=hrrr ┊ product=sfc ┊ 2021-Jul-01 12:00 UTC F06 ┊ GRIB2 @ aws ┊ IDX @ aws

# %%
H.download()
# Out:
# 👨🏻‍🏭 Created directory: [/Users/zliu/data/hrrr/20210701]
# 🚛💨  Download Progress: 100.00% of 171.9 MB
# PosixPath('/Users/zliu/data/hrrr/20210701/hrrr.t12z.wrfsfcf06.grib2')

# %%
H.xarray('TMP:2 m')
# Out:
# <xarray.Dataset>
# Dimensions:              (y: 1059, x: 1799)
# Coordinates:
#     time                 datetime64[ns] 2021-07-01T12:00:00
#     step                 timedelta64[ns] 06:00:00
#     heightAboveGround    float64 2.0
#     latitude             (y, x) float64 21.14 21.15 21.15 ... 47.86 47.85 47.84
#     longitude            (y, x) float64 237.3 237.3 237.3 ... 299.0 299.0 299.1
#     valid_time           datetime64[ns] 2021-07-01T18:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     t2m                  (y, x) float32 293.6 293.6 293.6 ... 284.3 284.3 284.3
#     gribfile_projection  object None
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     model:                   hrrr
#     product:                 sfc
# ...
